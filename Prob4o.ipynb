# %%
import os
import platform
import warnings
warnings.filterwarnings('ignore')

from tqdm.auto import tqdm
from utils import general_process
import numpy as np
import pickle
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from flaml import AutoML
import lightgbm as lgb
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import scienceplots
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.set_context('notebook')
sns.set_theme(style="ticks", palette="bright")
plt.style.use(['grid'])

# 设置字体
if platform.system() == 'Windows':
    plt.rcParams['font.sans-serif'] = ['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
else:
    plt.rcParams['font.family'] = ['Arial Unicode MS']

# 加载数据
filepath = 'train_data.pkl'
if not os.path.exists(filepath):
    general_process(output_filepath=filepath)
with open(filepath, 'rb') as fin:
    df = pickle.load(fin)

# 计算磁通密度的峰值
df['flux_density_max'] = df['flux_density'].apply(lambda r: np.max(r))
df['type_material'] = df['type_material'].astype('category')
df['type_waveform'] = df['type_waveform'].astype('category')

# 准备模型的输入和输出
X_train = df[['type_material', 'temp', 'freq', 'type_waveform', 'flux_density_max']]
y_train = df['core_loss']

# %%
type(X_train.head(1).iloc[0, 0])
# Out:
# str

# %% [markdown]
# ## 模型训练 & 自动调参

# %%
# Encode categorical variables
label_encoders = {}
for col in ['type_material', 'type_waveform']:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col])
    label_encoders[col] = le

# Define AutoML settings
automl_settings = {
    "time_budget": 360,  # in seconds
    "estimator_list": ['lgbm'],
    "metric": 'mape',
    "task": 'regression',
    "log_file_name": "automl.log",
    "early_stop": True,
    "eval_method": "cv",
    "seed": 1314,
    "verbose": 3,
    "log_type": "better",
    "ensemble": True
}

# Initialize and train the model
automl = AutoML()
automl.fit(X_train, y_train, **automl_settings)
# Out:
# [flaml.automl.logger: 09-25 02:46:35] {1693} INFO - task = regression
# [flaml.automl.logger: 09-25 02:46:35] {1700} INFO - Data split method: uniform
# [flaml.automl.logger: 09-25 02:46:35] {1703} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-25 02:46:35] {1801} INFO - Minimizing error metric: mape
# [flaml.automl.logger: 09-25 02:46:35] {1911} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:35] {2347} INFO - Estimated sufficient time budget=1026s. Estimated necessary time budget=1s.
# [flaml.automl.logger: 09-25 02:46:35] {2394} INFO -  at 0.1s,	estimator lgbm's best error=14.8988,	best estimator lgbm's best error=14.8988
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:35] {2394} INFO -  at 0.2s,	estimator lgbm's best error=14.0919,	best estimator lgbm's best error=14.0919
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:35] {2394} INFO -  at 0.3s,	estimator lgbm's best error=14.0919,	best estimator lgbm's best error=14.0919
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:35] {2394} INFO -  at 0.5s,	estimator lgbm's best error=7.2514,	best estimator lgbm's best error=7.2514
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:35] {2394} INFO -  at 0.5s,	estimator lgbm's best error=7.2514,	best estimator lgbm's best error=7.2514
# [flaml.automl.logger: 09-25 02:46:35] {2221} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:36] {2394} INFO -  at 0.7s,	estimator lgbm's best error=3.6272,	best estimator lgbm's best error=3.6272
# [flaml.automl.logger: 09-25 02:46:36] {2221} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:36] {2394} INFO -  at 1.0s,	estimator lgbm's best error=3.6272,	best estimator lgbm's best error=3.6272
# [flaml.automl.logger: 09-25 02:46:36] {2221} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:36] {2394} INFO -  at 1.2s,	estimator lgbm's best error=2.2586,	best estimator lgbm's best error=2.2586
# [flaml.automl.logger: 09-25 02:46:36] {2221} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:36] {2394} INFO -  at 1.5s,	estimator lgbm's best error=2.2586,	best estimator lgbm's best error=2.2586
# [flaml.automl.logger: 09-25 02:46:36] {2221} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:37] {2394} INFO -  at 1.7s,	estimator lgbm's best error=2.2586,	best estimator lgbm's best error=2.2586
# [flaml.automl.logger: 09-25 02:46:37] {2221} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:37] {2394} INFO -  at 2.0s,	estimator lgbm's best error=1.1563,	best estimator lgbm's best error=1.1563
# [flaml.automl.logger: 09-25 02:46:37] {2221} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:37] {2394} INFO -  at 2.4s,	estimator lgbm's best error=1.1563,	best estimator lgbm's best error=1.1563
# [flaml.automl.logger: 09-25 02:46:37] {2221} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:39] {2394} INFO -  at 4.1s,	estimator lgbm's best error=0.3339,	best estimator lgbm's best error=0.3339
# [flaml.automl.logger: 09-25 02:46:39] {2221} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:39] {2394} INFO -  at 4.6s,	estimator lgbm's best error=0.3339,	best estimator lgbm's best error=0.3339
# [flaml.automl.logger: 09-25 02:46:39] {2221} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:45] {2394} INFO -  at 10.2s,	estimator lgbm's best error=0.1739,	best estimator lgbm's best error=0.1739
# [flaml.automl.logger: 09-25 02:46:45] {2221} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:53] {2394} INFO -  at 18.5s,	estimator lgbm's best error=0.1739,	best estimator lgbm's best error=0.1739
# [flaml.automl.logger: 09-25 02:46:53] {2221} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 09-25 02:46:57] {2394} INFO -  at 21.8s,	estimator lgbm's best error=0.1739,	best estimator lgbm's best error=0.1739
# [flaml.automl.logger: 09-25 02:46:57] {2221} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:03] {2394} INFO -  at 28.0s,	estimator lgbm's best error=0.1669,	best estimator lgbm's best error=0.1669
# [flaml.automl.logger: 09-25 02:47:03] {2221} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:10] {2394} INFO -  at 34.7s,	estimator lgbm's best error=0.1669,	best estimator lgbm's best error=0.1669
# [flaml.automl.logger: 09-25 02:47:10] {2221} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:20] {2394} INFO -  at 45.4s,	estimator lgbm's best error=0.1669,	best estimator lgbm's best error=0.1669
# [flaml.automl.logger: 09-25 02:47:20] {2221} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:26] {2394} INFO -  at 51.4s,	estimator lgbm's best error=0.1669,	best estimator lgbm's best error=0.1669
# [flaml.automl.logger: 09-25 02:47:26] {2221} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:35] {2394} INFO -  at 60.5s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:47:35] {2221} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:42] {2394} INFO -  at 66.8s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:47:42] {2221} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:47] {2394} INFO -  at 71.9s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:47:47] {2221} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 09-25 02:47:53] {2394} INFO -  at 78.1s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:47:53] {2221} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:08] {2394} INFO -  at 93.0s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:08] {2221} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:11] {2394} INFO -  at 95.7s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:11] {2221} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:28] {2394} INFO -  at 112.9s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:28] {2221} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:29] {2394} INFO -  at 113.7s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:29] {2221} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:32] {2394} INFO -  at 117.6s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:32] {2221} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:39] {2394} INFO -  at 124.0s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:39] {2221} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:41] {2394} INFO -  at 126.1s,	estimator lgbm's best error=0.1373,	best estimator lgbm's best error=0.1373
# [flaml.automl.logger: 09-25 02:48:41] {2221} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 09-25 02:48:50] {2394} INFO -  at 135.5s,	estimator lgbm's best error=0.1258,	best estimator lgbm's best error=0.1258
# [flaml.automl.logger: 09-25 02:48:50] {2221} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 09-25 02:49:13] {2394} INFO -  at 157.8s,	estimator lgbm's best error=0.1258,	best estimator lgbm's best error=0.1258
# [flaml.automl.logger: 09-25 02:49:13] {2221} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 09-25 02:49:19] {2394} INFO -  at 164.3s,	estimator lgbm's best error=0.1258,	best estimator lgbm's best error=0.1258
# [flaml.automl.logger: 09-25 02:49:19] {2221} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 09-25 02:49:22] {2394} INFO -  at 167.3s,	estimator lgbm's best error=0.1258,	best estimator lgbm's best error=0.1258
# [flaml.automl.logger: 09-25 02:49:22] {2221} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 09-25 02:50:20] {2394} INFO -  at 224.8s,	estimator lgbm's best error=0.1080,	best estimator lgbm's best error=0.1080
# [flaml.automl.logger: 09-25 02:50:20] {2221} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 09-25 02:51:13] {2394} INFO -  at 278.1s,	estimator lgbm's best error=0.1080,	best estimator lgbm's best error=0.1080
# [flaml.automl.logger: 09-25 02:51:13] {2221} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 09-25 02:51:46] {2394} INFO -  at 311.5s,	estimator lgbm's best error=0.1080,	best estimator lgbm's best error=0.1080
# [flaml.automl.logger: 09-25 02:51:46] {2528} INFO - [('lgbm', {'n_jobs': -1, 'n_estimators': 205, 'num_leaves': 1075, 'min_child_samples': 27, 'learning_rate': 0.14652333386013233, 'colsample_bytree': 0.9200231305807232, 'reg_alpha': 0.007040542142797141, 'reg_lambda': 0.0029351158756900702, 'max_bin': 127, 'verbose': -1})]
# [flaml.automl.logger: 09-25 02:52:03] {2630} INFO - retrain lgbm for 17.1s
# [flaml.automl.logger: 09-25 02:52:03] {2633} INFO - retrained model: LGBMRegressor(colsample_bytree=0.9200231305807232,
#               learning_rate=0.14652333386013233, max_bin=127,
#               min_child_samples=27, n_estimators=1, n_jobs=-1, num_leaves=1075,
#               reg_alpha=0.007040542142797141, reg_lambda=0.0029351158756900702,
#               verbose=-1)
# [flaml.automl.logger: 09-25 02:52:03] {1941} INFO - fit succeeded
# [flaml.automl.logger: 09-25 02:52:03] {1942} INFO - Time taken to find the best model: 224.8278272151947

# %%
# Print the best hyperparameters and MAE
print('Best hyperparameter config:', automl.best_config)
print(f'Best {automl_settings["metric"].upper()}:', automl.best_loss)
print("Training duration of best run: {0:.4g} s".format(automl.best_config_train_time))
print(automl.model.estimator)
# Out:
# Best hyperparameter config: {'n_estimators': 205, 'num_leaves': 1075, 'min_child_samples': 27, 'learning_rate': 0.14652333386013233, 'log_max_bin': 7, 'colsample_bytree': 0.9200231305807232, 'reg_alpha': 0.007040542142797141, 'reg_lambda': 0.0029351158756900702}
# Best MAPE: 0.10802417338715378
# Training duration of best run: 17.06 s
# LGBMRegressor(colsample_bytree=0.9200231305807232,
#               learning_rate=0.14652333386013233, max_bin=127,
#               min_child_samples=27, n_estimators=1, n_jobs=-1, num_leaves=1075,
#               reg_alpha=0.007040542142797141, reg_lambda=0.0029351158756900702,
#               verbose=-1)

# %%
demo = np.array([1, 25, 50020, '正弦波', 0.031419])
demo = demo.reshape(1, -1)
automl.predict(demo)
# Out:
# array([5560.04287675])

# %%
from flaml.automl.data import get_output_from_log
import numpy as np

time_history, best_valid_loss_history, valid_loss_history, config_history, metric_history = get_output_from_log(
    filename=automl_settings['log_file_name'], time_budget=automl_settings['time_budget'])
plt.xlabel('时间 (s)')
plt.ylabel(f'验证集 {automl_settings["metric"].upper()}')
plt.step(time_history, np.array(best_valid_loss_history), where='post')
plt.scatter(time_history, np.array(best_valid_loss_history), alpha=0.3)
plt.savefig('figures/p4-learning_curve.pdf', bbox_inches='tight')

# %% [markdown]
# ## 特征重要性

# %%
mapping = {
    'type_material': '磁芯材料',
    'temp': '温度 $T$ (°C)',
    'freq': '频率 $f$ (Hz)',
    'type_waveform': '励磁波形',
    'flux_density_max': '磁通密度峰值$B_m$ (T)'
}

plt.barh([mapping.get(feature, feature) for feature in automl.feature_names_in_], automl.feature_importances_)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

# plot feature importance for split
lgb.plot_importance(automl.model.estimator, importance_type="split", title="LightGBM Feature Importance (Gain)", ax=axes[0])
axes[0].set_ylabel('')
axes[0].set_xlabel('')
axes[0].set_title('特征重要性(分裂次数)')
axes[0].set_yticklabels([mapping.get(label.get_text(), label.get_text()) for label in axes[0].get_yticklabels()])

# plot feature importance for gain
lgb.plot_importance(automl.model.estimator, importance_type="gain", title="LightGBM Feature Importance (Gain)", ax=axes[1], precision=0)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
axes[1].set_title('特征重要性(信息增益)')
axes[1].set_yticklabels([])
# axes[1].set_yticklabels([mapping.get(label.get_text(), label.get_text()) for label in axes[1].get_yticklabels()])
axes[1].set_xlim([0, 4e15])
plt.tight_layout()
plt.savefig('figures/p4-plot_importance.pdf', bbox_inches='tight')

# %%
# use the model to predict
y_pred = automl.predict(X_train)
# plot the predicted and actual values
plt.figure(figsize=(6, 6))
sns.scatterplot(x=y_train, y=y_pred, alpha=0.3)
plt.xlabel('磁芯损耗(真实值)')
plt.ylabel('磁芯损耗(预测值)')
plt.savefig('figures/p4-true_vs_pred.pdf', bbox_inches='tight')

# %% [markdown]
# ## 保存模型

# %%
with open('model_and_encoders2.pkl', 'wb') as f:
    pickle.dump({
        'model': automl,
        'label_encoders': label_encoders
    }, f)

# %%
# load the model
with open('model_and_encoders2.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

model = loaded_data['model']
label_encoders = loaded_data['label_encoders']

# %% [markdown]
# ## 测试结果

# %%
test_df = pd.read_excel('dataset/附件三（测试集）.xlsx')
column_mapping = {
    '温度，oC': 'temp',
    '频率，Hz': 'freq',
    '磁芯损耗，w/m3': 'core_loss',
    '0（磁通密度B，T）': 0,
    '励磁波形': 'type_waveform',
    '磁芯材料': 'type_material',
}
test_df.rename(columns=column_mapping, inplace=True)
test_df['flux_density'] = test_df.iloc[:, 5:].values.tolist()
test_df.drop(columns=[i for i in range(1024)], inplace=True)
test_df['flux_density_max'] = test_df['flux_density'].apply(lambda r: np.max(r))
test_df['type_material'] = test_df['type_material'].apply(lambda r: r.replace('材料', ''))
test_df.head(1)
# Out:
#    序号  temp   freq type_material type_waveform  \
# 0   1    25  56320             1           正弦波
#
#                                         flux_density  flux_density_max
# 0  [0.002215526, 0.002596693, 0.002976955, 0.0033...          0.062438

# %%
X_test = test_df[['type_material', 'temp', 'freq', 'type_waveform', 'flux_density_max']]
for col in ['type_material', 'type_waveform']:
    le = label_encoders[col]
    X_test[col] = le.transform(X_test[col])
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (400,)

# %%
# write to csv
test_df['core_loss'] = y_pred
test_df.drop(columns=['flux_density'], inplace=True)
test_df.to_csv('p4.csv', index=False)

# %%
test_df['core_loss_steinmetz'] = 1222.0 * test_df['freq'] ** 1.467 * test_df['flux_density_max'] ** 2.451 * \
    (0.001405 - 1.744 * 1e-5 * test_df['temp'] + 9.797 * 1e-8 * test_df['temp'] ** 2)
test_df.head(1)
# Out:
#    序号  temp   freq type_material type_waveform  flux_density_max  \
# 0   1    25  56320             1           正弦波          0.062438
#
#       core_loss  core_loss_steinmetz
# 0  18367.054079         13087.947426

# %%
selected_rows = test_df[test_df['序号'].isin([16, 76, 98, 126, 168, 230, 271, 338, 348, 379])]
result_table = selected_rows[['序号', 'core_loss']]
latex_table = result_table.to_latex(index=False, float_format="%.2f")
print(latex_table.replace('core_loss', '磁芯损耗预测结果'))
# Out:
# \begin{tabular}{rr}
# \toprule
# 序号 & 磁芯损耗预测结果 \\
# \midrule
# 16 & 752.05 \\
# 76 & 1747830.16 \\
# 98 & 14835.80 \\
# 126 & 1631.21 \\
# 168 & 75460.21 \\
# 230 & 67707.28 \\
# 271 & 2029521.65 \\
# 338 & 12733.19 \\
# 348 & 901416.17 \\
# 379 & 1264.94 \\
# \bottomrule
# \end{tabular}

# %%
# plot the predicted and actual values
plt.figure(figsize=(6, 6))
sns.regplot(data=test_df, x='core_loss', y='core_loss_steinmetz', robust=True)
# plt.scatter(test_df['core_loss'], test_df['core_loss_steinmetz'], alpha=0.3)
plt.xlabel('磁芯损耗(模型预测值)')
plt.ylabel('磁芯损耗(修正斯坦麦茨方程)')
plt.savefig('figures/p4-test-steinmetz_vs_pred.pdf', bbox_inches='tight')

# %% [markdown]
# ## 模型对比

# %%
from sklearn.metrics import r2_score
# use scipy to simplify function definition process and support Latex output
import sympy as sp
from sympy import symbols, exp, log, latex
from sympy.utilities.lambdify import lambdify
from scipy.optimize import curve_fit

freq, flux_density_max, temp = symbols('f B_m T', commutative=False)
k, alpha, beta, c, d, k1, k2, c1, c2 = symbols('k alpha beta c d k1 k2 c1 c2')


def def2numerical(function_definitions):
    numerical_functions = {}
    for name, expr, params in function_definitions:
        # create a lambda function for numerical computation
        func_num = lambdify(
            (freq, flux_density_max, temp, *params),
            expr,
            modules=['numpy']
        )
        # define a wrapper function for curve_fit

        def func_wrapper(xdata, *args, func_num=func_num):
            freq_data, flux_density_max_data, temp_data = xdata
            return func_num(freq_data, flux_density_max_data, temp_data, *args)
        numerical_functions[name] = (func_wrapper, params)
    return numerical_functions


function_definitions = [
    ('Steinmetz', k * freq**alpha * flux_density_max**beta + 0 * temp, [k, alpha, beta]),
    ('Quadratic', k * freq**alpha * flux_density_max**beta * (c1 * temp**2 + c2 * temp + d), [k, alpha, beta, c1, c2, d]),
    # ('Sigmoid', k * freq**alpha * flux_density_max**beta / (1 + exp(-(c * temp + d))), [k, alpha, beta, c, d]),
]

numerical_functions = def2numerical(function_definitions)
for name, (expr, params) in zip(numerical_functions.keys(), [item[1:] for item in function_definitions]):
    # print the function with parameters if fitting failed
    latex_expr = latex(expr, mul_symbol=' \cdot ')
    print(f"{name} & $P = {latex_expr}$ \\\\")

xdata = df[['freq', 'flux_density_max', 'temp']].values.T
ydata = df['core_loss'].values

popt_values = {}
eval_metrics = ['R2', 'MSE', 'RMSE', 'MAE']
scores = {metric: {} for metric in eval_metrics}

for name, (func, params) in numerical_functions.items():
    if scores['R2'].get(name) is None:
        name_model = 'LightGBM'
        df[f'core_loss_{name_model.lower()}'] = automl.predict(X_train)
        df[f'relative_error_{name_model.lower()}'] = (np.abs(df['core_loss'] - df[f'core_loss_{name_model.lower()}']) / df['core_loss']) * 100
        scores['R2'][name_model] = r2_score(ydata, df[f'core_loss_{name_model.lower()}'])
        scores['MSE'][name_model] = np.mean((ydata - df[f'core_loss_{name_model.lower()}'])**2)
        scores['RMSE'][name_model] = np.sqrt(scores['MSE'][name_model])
        scores['MAE'][name_model] = np.mean(np.abs(ydata - df[f'core_loss_{name_model.lower()}']))
    xxdata = xdata
    p0 = [1.0, 2, 2.5] + [0.0] * (len(params) - 3)
    popt, _ = curve_fit(func, xxdata, ydata, p0=p0, maxfev=10000)
    popt_values[name] = popt
    df[f'core_loss_{name.lower()}'] = func(xxdata, *popt)
    df[f'relative_error_{name.lower()}'] = (np.abs(df['core_loss'] - df[f'core_loss_{name.lower()}']) / df['core_loss']) * 100

    # calculate evaluation metrics
    scores['R2'][name] = r2_score(ydata, df[f'core_loss_{name.lower()}'])
    scores['MSE'][name] = np.mean((ydata - df[f'core_loss_{name.lower()}'])**2)
    scores['RMSE'][name] = np.sqrt(scores['MSE'][name])
    scores['MAE'][name] = np.mean(np.abs(ydata - df[f'core_loss_{name.lower()}']))

for name, (expr, params) in zip(numerical_functions.keys(), [item[1:] for item in function_definitions]):
    popt = popt_values.get(name)
    if popt is not None:
        # create a dictionary of parameter substitutions
        param_subs = dict(zip(params, popt))
        # substitute numerical values into the symbolic expression
        expr_subs = expr.subs(param_subs)
        # round numerical values to four decimal places
        expr_subs = expr_subs.evalf(4)
        # generate LaTeX expression
        latex_expr = latex(expr_subs, mul_symbol=' \cdot ')
        print(f"{name} & $P = {latex_expr}$ \\\\")

# create a new dataframe for plotting
plot_df = pd.DataFrame()
for name, (func, _) in list(numerical_functions.items()) + [('LightGBM', (None, []))]:
    temp_df = df[['temp', f'relative_error_{name.lower()}']].copy()
    temp_df['Function'] = name
    temp_df.rename(columns={f'relative_error_{name.lower()}': 'Relative Error'}, inplace=True)
    temp_df['R2'] = scores['R2'][name]
    temp_df['MSE'] = scores['MSE'][name]
    temp_df['RMSE'] = scores['RMSE'][name]
    temp_df['MAE'] = scores['MAE'][name]
    plot_df = pd.concat([plot_df, temp_df], ignore_index=True)

# create a dataframe for LaTeX table
latex_df = pd.DataFrame(scores)

# find the minimum error values and mark them with bold and asterisk
for metric in eval_metrics:
    value = latex_df[metric].min()
    if metric == 'R2':
        value = latex_df[metric].max()
    latex_df[metric] = latex_df[metric].apply(lambda x: f"\\textbf{{{x:.4f}}}*" if x == value else f"{x:.4f}")

# plot boxplot with hue as different functions
plt.figure(figsize=(12, 6))
sns.boxplot(data=plot_df, x='temp', y='Relative Error', hue='Function', boxprops=dict(alpha=.65))
plt.ylabel("相对误差绝对值 (%)")
plt.xlabel("温度 (°C)")
plt.legend(title='对比模型')
plt.tight_layout()
plt.savefig('figures/p4-error-contrast.pdf', bbox_inches='tight')
# Out:
# Steinmetz & $P = k \cdot f^{\alpha} \cdot B_{m}^{\beta}$ \\
# Quadratic & $P = k \cdot f^{\alpha} \cdot B_{m}^{\beta} \cdot \left(c_{1} \cdot T^{2} + c_{2} \cdot T + d\right)$ \\
# Steinmetz & $P = 2.427 \cdot f^{1.365} \cdot B_{m}^{2.127}$ \\
# Quadratic & $P = 3465.0 \cdot f^{1.348} \cdot B_{m}^{2.118} \cdot \left(0.001303 - 1.295 \cdot 10^{-5} \cdot T + 7.57 \cdot 10^{-8} \cdot T^{2}\right)$ \\

# %%
latex_table = latex_df.to_latex(index=True, caption='Evaluation Metrics for Different Functions')
print(latex_table)
# Out:
# \begin{table}
# \caption{Evaluation Metrics for Different Functions}
# \begin{tabular}{lllll}
# \toprule
#  & R2 & MSE & RMSE & MAE \\
# \midrule
# LightGBM & \textbf{0.9969}* & \textbf{438575478.0535}* & \textbf{20942.1937}* & \textbf{7194.7990}* \\
# Steinmetz & 0.9359 & 9073983602.2359 & 95257.4596 & 47756.1462 \\
# Quadratic & 0.9561 & 6214319763.7441 & 78830.9569 & 41800.2294 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## 泛化能力

# %%
df['flux_density_max'].describe()
# Out:
# count    12400.000000
# mean         0.077533
# std          0.067873
# min          0.009638
# 25%          0.027441
# 50%          0.049793
# 75%          0.100297
# max          0.313284
# Name: flux_density_max, dtype: float64

# %%
df.shape
# Out:
# (12400, 13)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))


def create_demo_df(n, freq, flux_density_max, temp, type_waveform, type_material):
    return pd.DataFrame({
        'freq': freq,
        'flux_density_max': flux_density_max,
        'temp': temp,
        'type_waveform': type_waveform,
        'type_material': type_material
    })


def encode_columns(df, columns):
    for col in columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        label_encoders[col] = le
    return df


def plot_prediction(df, x_col, ax):
    y_pred = model.predict(df)
    y_se = 1222.0 * df['freq'] ** 1.467 * df['flux_density_max'] ** 2.451 * \
        (0.001405 - 1.744 * 1e-5 * df['temp'] + 9.797 * 1e-8 * df['temp'] ** 2)
    sns.scatterplot(x=df[x_col], y=y_pred, ax=ax, label='模型预测')
    sns.lineplot(x=df[x_col], y=y_se, ax=ax, color='red', label='修正斯坦麦茨方程')


n = 100
df_demo = create_demo_df(
    n,
    [106840.8] * n,
    [0.27029] * n,
    np.linspace(20, 100, n),
    ['正弦波'] * n,
    ['1'] * n
)
df_demo = encode_columns(df_demo, ['type_material', 'type_waveform'])
plot_prediction(df_demo, 'temp', axes[0])

df_demo = create_demo_df(
    n,
    np.linspace(89210, 551240, n),
    [0.27029] * n,
    [25] * n,
    ['正弦波'] * n,
    ['1'] * n
)
df_demo = encode_columns(df_demo, ['type_material', 'type_waveform'])
plot_prediction(df_demo, 'freq', axes[1])

df_demo = create_demo_df(
    n,
    [106840.8] * n,
    np.linspace(0.027448, 0.31384, n),
    [25] * n,
    ['正弦波'] * n,
    ['1'] * n
)
df_demo = encode_columns(df_demo, ['type_material', 'type_waveform'])
plot_prediction(df_demo, 'flux_density_max', axes[2])

axes[0].set_title('温度 vs 磁芯损耗')
axes[0].set_xlabel('温度 (°C)')
axes[1].set_title('频率 vs 磁芯损耗')
axes[1].set_xlabel('频率 (Hz)')
axes[2].set_title('磁通密度峰值 vs 磁芯损耗')
axes[2].set_xlabel('磁通密度峰值')
axes[0].set_ylabel('磁芯损耗')
plt.savefig('figures/p4-generalizable-tree.pdf', bbox_inches='tight')
